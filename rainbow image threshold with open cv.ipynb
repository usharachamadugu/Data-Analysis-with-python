# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#reading the image 

img = cv2.imread(r'C:\Users\Sai\Desktop\DATA SCIENCE\rainbow.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = cv2.imread(r'C:\Users\Sai\Desktop\DATA SCIENCE\rainbow.jpg', 0) #0 for gray scale
plt.imshow(img, cmap='gray')

# %%
ret,thresh1=cv2.threshold(img,127,255,cv2.THRESH_BINARY) #value belo 127 == 0 and avobe to 255

ret


plt.imshow(thresh1,cmap='gray')

# %%
#another type thresh.
ret,thresh1=cv2.threshold(img,127,255,cv2.THRESH_TRUNC) #value belo 127 == 0 and avobe to 255
plt.imshow(thresh1,cmap='gray')
